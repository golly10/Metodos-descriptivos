# %% [markdown]
# # Tema 2: Actividad 1 - Ejecución de FP-Growth
# ### Autor: Juan José Méndez Torrero

# %%
import pandas as pd
import numpy as np

data = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data', sep=",")

columns = ["age","workclass","fnlwgt","education","education-num","marital-status","occupation","relationship","race","sex","capital-gain","capital-loss","hours-per-week","native-country", "class"]

data.columns = columns

# %%
data = data.drop("fnlwgt", axis=1)

data["age"] = pd.cut(data["age"], bins=3, right=False)
data["education-num"] = pd.cut(data["education-num"], bins=3, right=False)
data["capital-gain"] = pd.cut(data["capital-gain"], bins=3, right=False)
data["capital-loss"] = pd.cut(data["capital-loss"], bins=3, right=False)
data["hours-per-week"] = pd.cut(data["hours-per-week"], bins=3, right=False)

data
# Out:
#                     age          workclass    education   education-num  \
# 0      [41.333, 65.667)   Self-emp-not-inc    Bachelors  [11.0, 16.015)
# 1        [17.0, 41.333)            Private      HS-grad     [6.0, 11.0)
# 2      [41.333, 65.667)            Private         11th     [6.0, 11.0)
# 3        [17.0, 41.333)            Private    Bachelors  [11.0, 16.015)
# 4        [17.0, 41.333)            Private      Masters  [11.0, 16.015)
# ...                 ...                ...          ...             ...
# 32555    [17.0, 41.333)            Private   Assoc-acdm  [11.0, 16.015)
# 32556    [17.0, 41.333)            Private      HS-grad     [6.0, 11.0)
# 32557  [41.333, 65.667)            Private      HS-grad     [6.0, 11.0)
# 32558    [17.0, 41.333)            Private      HS-grad     [6.0, 11.0)
# 32559  [41.333, 65.667)       Self-emp-inc      HS-grad     [6.0, 11.0)
#
#             marital-status          occupation    relationship    race  \
# ...

# %%
data_encoded = pd.get_dummies(data)

data_encoded
# Out:
#        age_[17.0, 41.333)  age_[41.333, 65.667)  age_[65.667, 90.073)  \
# 0                       0                     1                     0
# 1                       1                     0                     0
# 2                       0                     1                     0
# 3                       1                     0                     0
# 4                       1                     0                     0
# ...                   ...                   ...                   ...
# 32555                   1                     0                     0
# 32556                   1                     0                     0
# 32557                   0                     1                     0
# 32558                   1                     0                     0
# 32559                   0                     1                     0
#
#        workclass_ ?  workclass_ Federal-gov  workclass_ Local-gov  \
# ...

# %%
from mlxtend.frequent_patterns import fpgrowth

# %%
results = fpgrowth(data_encoded, min_support=0.1, use_colnames=True)

lengths = [len(x) for x in results["itemsets"]]

print("La máxima longitud del itemset encontrado es: {0}".format(max(lengths)))

res_50 = pd.DataFrame()
for sup, items in zip(results["support"], results["itemsets"]):

    for itm in items:

        if "class_" in itm:
            res_50 = res_50.append(pd.Series([sup, items]), ignore_index=True)

res_50.columns = results.columns

print(results)

print(res_50)
# Out:
# La máxima longitud del itemset encontrado es: 10
#        support                                           itemsets
# 0     0.994902                      (capital-gain_[0.0, 33333.0))
# 1     0.955958                       (capital-loss_[0.0, 1452.0))
# 2     0.895854                    (native-country_ United-States)
# 3     0.854269                                      (race_ White)
# 4     0.759183                                     (class_ <=50K)
# ...        ...                                                ...
# 8211  0.104238  (capital-gain_[0.0, 33333.0), occupation_ Craf...
# 8212  0.103900  (capital-gain_[0.0, 33333.0), occupation_ Craf...
# 8213  0.105713  (capital-gain_[0.0, 33333.0), relationship_ Un...
# 8214  0.104238  (capital-loss_[0.0, 1452.0), relationship_ Unm...
# 8215  0.104115  (capital-gain_[0.0, 33333.0), capital-loss_[0....
#
# [8216 rows x 2 columns]
#        support                                           itemsets
# ...

# %%
results = fpgrowth(data_encoded, min_support=0.3, use_colnames=True)

lengths = [len(x) for x in results["itemsets"]]

print("La máxima longitud del itemset encontrado es: {0}".format(max(lengths)))

res_50 = pd.DataFrame()
for sup, items in zip(results["support"], results["itemsets"]):

    for itm in items:

        if "class_" in itm:
            res_50 = res_50.append(pd.Series([sup, items]), ignore_index=True)

res_50.columns = results.columns

print(results)

print(res_50)
# Out:
# La máxima longitud del itemset encontrado es: 7
#       support                                           itemsets
# 0    0.994902                      (capital-gain_[0.0, 33333.0))
# 1    0.955958                       (capital-loss_[0.0, 1452.0))
# 2    0.895854                    (native-country_ United-States)
# 3    0.854269                                      (race_ White)
# 4    0.759183                                     (class_ <=50K)
# ..        ...                                                ...
# 712  0.312991      (class_ <=50K, marital-status_ Never-married)
# 713  0.318857  (capital-gain_[0.0, 33333.0), marital-status_ ...
# 714  0.312869  (capital-gain_[0.0, 33333.0), marital-status_ ...
# 715  0.305590  (class_ <=50K, marital-status_ Never-married, ...
# 716  0.305467  (capital-gain_[0.0, 33333.0), marital-status_ ...
#
# [717 rows x 2 columns]
#       support                                           itemsets
# ...

# %%
results = fpgrowth(data_encoded, min_support=0.5, use_colnames=True)

lengths = [len(x) for x in results["itemsets"]]

print("La máxima longitud del itemset encontrado es: {0}".format(max(lengths)))

res_50 = pd.DataFrame()
for sup, items in zip(results["support"], results["itemsets"]):

    for itm in items:

        if "class_" in itm:
            res_50 = res_50.append(pd.Series([sup, items]), ignore_index=True)

res_50.columns = results.columns

print(results)

print(res_50)
# Out:
# La máxima longitud del itemset encontrado es: 5
#       support                                           itemsets
# 0    0.994902                      (capital-gain_[0.0, 33333.0))
# 1    0.955958                       (capital-loss_[0.0, 1452.0))
# 2    0.895854                    (native-country_ United-States)
# 3    0.854269                                      (race_ White)
# 4    0.759183                                     (class_ <=50K)
# ..        ...                                                ...
# 126  0.543428  (capital-gain_[0.0, 33333.0), age_[17.0, 41.33...
# 127  0.524355  (age_[17.0, 41.333), capital-loss_[0.0, 1452.0...
# 128  0.522819  (capital-gain_[0.0, 33333.0), age_[17.0, 41.33...
# 129  0.516370  (capital-gain_[0.0, 33333.0), age_[17.0, 41.33...
# 130  0.508385  (capital-gain_[0.0, 33333.0), age_[17.0, 41.33...
#
# [131 rows x 2 columns]
#      support                                           itemsets
# ...

# %%
results = fpgrowth(data_encoded, min_support=0.7, use_colnames=True)

lengths = [len(x) for x in results["itemsets"]]

print("La máxima longitud del itemset encontrado es: {0}".format(max(lengths)))

res_50 = pd.DataFrame()
for sup, items in zip(results["support"], results["itemsets"]):

    for itm in items:

        if "class_" in itm:
            res_50 = res_50.append(pd.Series([sup, items]), ignore_index=True)

res_50.columns = results.columns

print(results)

print(res_50)
# Out:
# La máxima longitud del itemset encontrado es: 4
#      support                                           itemsets
# 0   0.994902                      (capital-gain_[0.0, 33333.0))
# 1   0.955958                       (capital-loss_[0.0, 1452.0))
# 2   0.895854                    (native-country_ United-States)
# 3   0.854269                                      (race_ White)
# 4   0.759183                                     (class_ <=50K)
# 5   0.804668                  (hours-per-week_[33.667, 66.333))
# 6   0.950860  (capital-gain_[0.0, 33333.0), capital-loss_[0....
# 7   0.891308  (capital-gain_[0.0, 33333.0), native-country_ ...
# 8   0.855866  (capital-loss_[0.0, 1452.0), native-country_ U...
# 9   0.851321  (capital-gain_[0.0, 33333.0), capital-loss_[0....
# 10  0.849785         (capital-gain_[0.0, 33333.0), race_ White)
# 11  0.815295          (capital-loss_[0.0, 1452.0), race_ White)
# 12  0.786855       (race_ White, native-country_ United-States)
# ...

# %%
res_50["itemsets"][3]
# Out:
# frozenset({'capital-gain_[0.0, 33333.0)',
#            'capital-loss_[0.0, 1452.0)',
#            'class_ <=50K'})
